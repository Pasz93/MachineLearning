# %% [markdown]
# <a href="https://colab.research.google.com/github/Pasz93/MachineLearning/blob/main/Previs%C3%A3o_Classificacao_Prox_Jogos_Bundesliga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# Faz uma requisição para obter os dados da página da Wikipedia
requisicao = requests.get("https://pt.wikipedia.org/wiki/Bundesliga_de_2023%E2%80%9324")

# Extrai todas as tabelas presentes na página e armazena em 'tabelas'
tabelas = pd.read_html(requisicao.text)

# Seleciona as tabelas de classificação e de jogos
tabela_classificacao = tabelas[8]
tabela_jogos = tabelas[11]

# Exibe as tabelas de classificação e de jogos
display(tabela_classificacao)
display(tabela_jogos)
# Out:
#     Pos                    Equipe  Pts   J   V  E   D  GP  GC   SG  \
# 0     1          Bayer Leverkusen   42  16  13  3   0  46  12  +34
# 1     2         Bayern de Munique   38  15  12  2   1  49  15  +34
# 2     3                 Stuttgart   34  16  11  1   4  37  19  +18
# 3     4                RB Leipzig   33  16  10  3   3  38  17  +21
# 4     5         Borussia Dortmund   27  16   7  6   3  30  25   +5
# 5     6       Eintracht Frankfurt   24  16   6  6   4  26  20   +6
# 6     7                Hoffenheim   24  16   7  3   6  32  30   +2
# 7     8                  Freiburg   24  16   7  3   6  21  26   −5
# 8     9                Heidenheim   20  16   6  2   8  25  31   −6
# 9    10                 Wolfsburg   19  16   6  1   9  20  27   −7
# 10   11                  Augsburg   18  16   4  6   6  24  31   −7
# 11   12  Borussia Mönchengladbach   17  16   4  5   7  31  35   −4
# 12   13             Werder Bremen   16  16   4  4   8  23  30   −7
# 13   14                    Bochum   16  16   3  7   6  18  33  −15
# 14   15              Union Berlin   13  15   4  1  10  17  31  −14
# 15   16                  Mainz 05   10  16   1  7   8  13  28  −15
# 16   17                      Köln   10  16   2  4  10  10  28  −18
# 17   18              Darmstadt 98   10  16   2  4  10  20  41  −21
#
#                             Classificação ou descenso
# 0   Fase de grupos da Liga dos Campeões da UEFA de...
# 1   Fase de grupos da Liga dos Campeões da UEFA de...
# 2   Fase de grupos da Liga dos Campeões da UEFA de...
# 3   Fase de grupos da Liga dos Campeões da UEFA de...
# 4       Fase de grupos da Liga Europa da UEFA 2024–25
# 5      Play-off da Liga Conferência Europa de 2024–25
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                           Playoffs de rebaixamento
# 16               Rebaixado à 2. Bundesliga de 2024–25
# 17               Rebaixado à 2. Bundesliga de 2024–25
#                  Casa \ Fora  AUG  BOC  BRE  DAR  DOR  FRA  FRE  HEI  HOF  \
# 0                   Augsburg    —  2–2  NaN  1–2  1–1  2–1  NaN  NaN  1–1
# 1                     Bochum  NaN    —  NaN  NaN  1–1  1–1  NaN  NaN  NaN
# 2              Werder Bremen  2–0  NaN    —  NaN  NaN  2–2  NaN  NaN  2–3
# 3               Darmstadt 98  NaN  1–2  4–2    —  NaN  NaN  NaN  NaN  NaN
# 4          Borussia Dortmund  NaN  NaN  1–0  NaN    —  NaN  NaN  2–2  NaN
# 5        Eintracht Frankfurt  NaN  NaN  NaN  1–0  3–3    —  0–0  2–0  NaN
# 6                   Freiburg  2–0  2–1  1–0  1–1  2–4  NaN    —  NaN  NaN
# 7                 Heidenheim  2–5  0–0  4–2  3–2  NaN  NaN  3–2    —  2–3
# 8                 Hoffenheim  NaN  3–1  NaN  3–3  1–3  1–3  1–2  NaN    —
# 9                       Köln  1–1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  1–3
# 10                RB Leipzig  3–0  0–0  NaN  NaN  NaN  NaN  3–1  2–1  3–1
# 11          Bayer Leverkusen  NaN  NaN  NaN  5–1  1–1  3–0  2–1  4–1  NaN
# 12                  Mainz 05  NaN  NaN  NaN  NaN  NaN  1–1  0–1  0–1  NaN
# 13  Borussia Mönchengladbach  NaN  NaN  2–2  NaN  NaN  NaN  NaN  NaN  2–1
# 14         Bayern de Munique  3–1  7–0  NaN  8–0    a  NaN  3–0  4–2  NaN
# 15                 Stuttgart  3–0  5–0  2–0  3–1  2–1  NaN  5–0  NaN  2–3
# 16              Union Berlin  1–1  NaN  NaN  NaN  NaN  0–3  NaN  NaN  0–2
# 17                 Wolfsburg  NaN  NaN  2–2  NaN  NaN  2–0  0–1  2–0  NaN
#
#     KÖL  LEI  LEV  MAI  MÖN  MUN  STU  UNB  WOL
# 0   NaN  NaN  NaN  2–1  4–4  NaN  NaN  NaN  3–2
# 1   1–1  NaN  NaN  2–2  1–3  NaN  NaN  3–0  NaN
# 2   2–1  1–1  0–3  4–0  NaN  0–4  NaN  2–0  NaN
# 3   0–1  1–3  NaN  0–0  3–3  NaN  NaN  1–4  0–1
# 4   1–0  2–3  NaN  1–1  4–2  0–4  NaN  4–2  1–0
# 5   1–1  NaN  NaN  NaN  2–1  5–1  1–2  NaN  NaN
# 6   2–0  NaN  NaN  NaN  3–3  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN  NaN  NaN  2–0  1–0  NaN
# 8   NaN  NaN  2–3  1–1  NaN  NaN  NaN  NaN  3–1
# 9     —  NaN  NaN  0–0  3–1  0–1  0–2  NaN  1–2
# 10  6–0    —  NaN  NaN  NaN  2–2  5–1  NaN  NaN
# 11  3–0  3–2    —  NaN  NaN  NaN  NaN  4–0  NaN
# 12  NaN  2–0  0–3    —  NaN  1–3  1–3  NaN  NaN
# 13  NaN  0–1  0–3  2–2    —  1–2  NaN  NaN  4–0
# 14  NaN  NaN  2–2  NaN  NaN    —  3–0  NaN  NaN
# 15  NaN  NaN  1–1  NaN  NaN  NaN    —  NaN  3–1
# 16  2–0  0–3  NaN  4–1  3–1  NaN  0–3    —  NaN
# 17  NaN  2–1  1–2  NaN  NaN  1–2  NaN  2–1    —

# %%
# Cria um mapeamento de apelidos para nomes completos dos times
nomes_times = list(tabela_jogos["Casa \ Fora"])
apelidos = list(tabela_jogos.columns)
apelidos.pop(0)
de_para_times = dict(zip(apelidos,nomes_times))

# Imprime o mapeamento dos apelidos para nomes completos
print (de_para_times)
# Out:
# {'AUG': 'Augsburg', 'BOC': 'Bochum', 'BRE': 'Werder Bremen', 'DAR': 'Darmstadt 98', 'DOR': 'Borussia Dortmund', 'FRA': 'Eintracht Frankfurt', 'FRE': 'Freiburg', 'HEI': 'Heidenheim', 'HOF': 'Hoffenheim', 'KÖL': 'Köln', 'LEI': 'RB Leipzig', 'LEV': 'Bayer Leverkusen', 'MAI': 'Mainz 05', 'MÖN': 'Borussia Mönchengladbach', 'MUN': 'Bayern de Munique', 'STU': 'Stuttgart', 'UNB': 'Union Berlin', 'WOL': 'Wolfsburg'}

# %%
# Ajusta a estrutura da tabela de jogos para separar os nomes dos times e o placar
tabela_jogos_ajustada = tabela_jogos.set_index("Casa \ Fora")
tabela_jogos_ajustada = tabela_jogos_ajustada.unstack().reset_index()
tabela_jogos_ajustada = tabela_jogos_ajustada.rename(columns={"level_0": "Fora", "Casa \ Fora": "Casa",0: "Placar"})

# Define função para ajustar apelidos dos times nos nomes completos
def ajustar_apelido_time(linha):
  apelidos=linha["Fora"]
  nome = de_para_times[apelidos]
  return nome

# Aplica a função para ajustar os apelidos dos times na tabela de jogos
tabela_jogos_ajustada["Fora"] = tabela_jogos_ajustada.apply(ajustar_apelido_time, axis=1)

# Filtra os jogos onde o time da casa é diferente do time visitante
tabela_jogos_ajustada = tabela_jogos_ajustada[tabela_jogos_ajustada["Fora"]!=tabela_jogos_ajustada["Casa"]]

# Exibe os jogos futuros
display(tabela_jogos_ajustada)
# Out:
#           Fora                      Casa Placar
# 1     Augsburg                    Bochum    NaN
# 2     Augsburg             Werder Bremen    2–0
# 3     Augsburg              Darmstadt 98    NaN
# 4     Augsburg         Borussia Dortmund    NaN
# 5     Augsburg       Eintracht Frankfurt    NaN
# ..         ...                       ...    ...
# 318  Wolfsburg                  Mainz 05    NaN
# 319  Wolfsburg  Borussia Mönchengladbach    4–0
# 320  Wolfsburg         Bayern de Munique    NaN
# 321  Wolfsburg                 Stuttgart    3–1
# 322  Wolfsburg              Union Berlin    NaN
#
# [306 rows x 3 columns]

# %%
# Preenche os jogos ainda não realizados com "a jogar"
tabela_jogos_ajustada["Placar"] = tabela_jogos_ajustada["Placar"].fillna("a jogar")

# Separa os jogos já realizados dos jogos futuros
tabela_jogos_realizados = tabela_jogos_ajustada[tabela_jogos_ajustada["Placar"].str.contains("–")]
tabela_jogos_faltantes = tabela_jogos_ajustada[~tabela_jogos_ajustada["Placar"].str.contains("–")]
tabela_jogos_faltantes = tabela_jogos_faltantes.drop(columns=["Placar"])

# Exibe os jogos futuros
display(tabela_jogos_faltantes)
# Out:
#           Fora                 Casa
# 1     Augsburg               Bochum
# 3     Augsburg         Darmstadt 98
# 4     Augsburg    Borussia Dortmund
# 5     Augsburg  Eintracht Frankfurt
# 8     Augsburg           Hoffenheim
# ..         ...                  ...
# 316  Wolfsburg           RB Leipzig
# 317  Wolfsburg     Bayer Leverkusen
# 318  Wolfsburg             Mainz 05
# 320  Wolfsburg    Bayern de Munique
# 322  Wolfsburg         Union Berlin
#
# [166 rows x 2 columns]

# %%
# Separa os gols feitos em casa e fora nos jogos realizados
colunas = ["gols_casa", "gols_fora"]
tabela_jogos_realizados[colunas] = tabela_jogos_realizados["Placar"].str.split("–", expand=True)
tabela_jogos_realizados = tabela_jogos_realizados.drop(columns=["Placar"])
tabela_jogos_realizados["gols_casa"] = tabela_jogos_realizados["gols_casa"].astype(int)
tabela_jogos_realizados["gols_fora"] = tabela_jogos_realizados["gols_fora"].astype(int)

# Exibe os gols feitos em jogos já realizados
display(tabela_jogos_realizados)
# Out:
# <ipython-input-5-4f3c2081e06d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_jogos_realizados[colunas] = tabela_jogos_realizados["Placar"].str.split("–", expand=True)
# <ipython-input-5-4f3c2081e06d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_jogos_realizados[colunas] = tabela_jogos_realizados["Placar"].str.split("–", expand=True)
#           Fora                      Casa  gols_casa  gols_fora
# 2     Augsburg             Werder Bremen          2          0
# 6     Augsburg                  Freiburg          2          0
# 7     Augsburg                Heidenheim          2          5
# 9     Augsburg                      Köln          1          1
# 10    Augsburg                RB Leipzig          3          0
# ..         ...                       ...        ...        ...
# 310  Wolfsburg         Borussia Dortmund          1          0
# 314  Wolfsburg                Hoffenheim          3          1
# 315  Wolfsburg                      Köln          1          2
# 319  Wolfsburg  Borussia Mönchengladbach          4          0
# 321  Wolfsburg                 Stuttgart          3          1
#
# [140 rows x 4 columns]

# %%
# Calcula as médias de gols feitos e sofridos em casa e fora para cada time
media_gols_casa = tabela_jogos_realizados.groupby("Casa").mean(numeric_only=True)
media_gols_casa = media_gols_casa.rename(columns={"gols_casa": "gols_feitos_casa", "gols_fora": "gols_sofridos_casa"})
media_gols_fora = tabela_jogos_realizados.groupby("Fora").mean(numeric_only=True)
media_gols_fora = media_gols_fora.rename(columns={"gols_casa": "gols_sofridos_fora", "gols_fora": "gols_feitos_fora"})

# %%
# Cria a tabela de estatísticas com as médias de gols
tabela_estatisticas = media_gols_casa.merge(media_gols_fora, left_index=True, right_index=True)
tabela_estatisticas = tabela_estatisticas.reset_index()
tabela_estatisticas = tabela_estatisticas.rename(columns={"Casa": "time"})
display(tabela_estatisticas)
# Out:
#                         time  gols_feitos_casa  gols_sofridos_casa  \
# 0                   Augsburg          2.000000            1.750000
# 1           Bayer Leverkusen          3.125000            0.750000
# 2          Bayern de Munique          4.285714            0.714286
# 3                     Bochum          1.500000            1.333333
# 4          Borussia Dortmund          1.777778            1.555556
# 5   Borussia Mönchengladbach          1.571429            1.571429
# 6               Darmstadt 98          1.250000            2.000000
# 7        Eintracht Frankfurt          1.875000            1.000000
# 8                   Freiburg          1.857143            1.285714
# 9                 Heidenheim          2.125000            1.750000
# 10                Hoffenheim          1.875000            2.125000
# 11                      Köln          0.857143            1.428571
# 12                  Mainz 05          0.714286            1.714286
# 13                RB Leipzig          3.000000            0.750000
# 14                 Stuttgart          2.888889            0.777778
# 15              Union Berlin          1.250000            1.750000
# 16             Werder Bremen          1.666667            1.555556
# 17                 Wolfsburg          1.500000            1.125000
#
#     gols_sofridos_fora  gols_feitos_fora
# 0             2.125000          1.000000
# 1             0.857143          2.428571
# 2             1.250000          2.375000
# 3             2.500000          0.750000
# 4             1.571429          2.000000
# 5             2.875000          2.250000
# 6             3.125000          1.250000
# 7             1.500000          1.375000
# 8             1.888889          0.888889
# 9             2.285714          1.000000
# 10            1.625000          2.125000
# 11            2.000000          0.444444
# 12            1.777778          0.888889
# 13            1.375000          1.750000
# 14            1.714286          1.571429
# 15            2.428571          1.000000
# 16            2.285714          1.142857
# 17            2.142857          1.000000

# %%
from scipy.stats import poisson

# Define a função para calcular as pontuações esperadas para os jogos futuros
def calcular_pontuacao_esperada (linha):
  time_casa = linha["Casa"]
  time_fora = linha["Fora"]

  lambda_casa = tabela_estatisticas.loc[tabela_estatisticas["time"] == time_casa, "gols_feitos_casa"].iloc[0] * tabela_estatisticas.loc[tabela_estatisticas["time"] == time_fora, "gols_sofridos_fora"].iloc[0]

  lambda_fora = tabela_estatisticas.loc[tabela_estatisticas["time"] == time_fora, "gols_feitos_fora"].iloc[0] * tabela_estatisticas.loc[tabela_estatisticas["time"] == time_casa, "gols_sofridos_casa"].iloc[0]

  pv_casa = 0
  p_empate = 0
  pv_fora = 0

# Calcula as probabilidades de resultados possíveis para cada jogo futuro
  for gols_casa in range(8):
      for gols_fora in range(8):
          probabilidade_resultado = poisson.pmf(gols_casa, lambda_casa) * poisson.pmf(gols_fora, lambda_fora)
          if gols_casa == gols_fora:
            p_empate += probabilidade_resultado
          elif gols_casa > gols_fora:
            pv_casa += probabilidade_resultado
          elif gols_casa <  gols_fora:
            pv_fora += probabilidade_resultado

# Calcula as pontuações esperadas para cada time
  valor_esperado_casa = pv_casa * 3 + p_empate
  valor_esperado_fora = pv_fora * 3 + p_empate
  linha["pontos_casa"] = valor_esperado_casa
  linha["pontos_fora"] = valor_esperado_fora
  return linha

# %%
# Aplica o cálculo das pontuações esperadas para os jogos futuros
tabela_jogos_faltantes = tabela_jogos_faltantes.apply(calcular_pontuacao_esperada, axis=1)
display(tabela_jogos_faltantes)
# Out:
#           Fora                 Casa  pontos_casa  pontos_fora
# 1     Augsburg               Bochum     2.300788     0.512737
# 3     Augsburg         Darmstadt 98     1.739850     1.055796
# 4     Augsburg    Borussia Dortmund     2.319277     0.448259
# 5     Augsburg  Eintracht Frankfurt     2.552475     0.220039
# 8     Augsburg           Hoffenheim     2.101350     0.616762
# ..         ...                  ...          ...          ...
# 316  Wolfsburg           RB Leipzig     2.011270     0.026124
# 317  Wolfsburg     Bayer Leverkusen     1.900087     0.021406
# 318  Wolfsburg             Mainz 05     1.266872     1.499878
# 320  Wolfsburg    Bayern de Munique     0.904009     0.002949
# 322  Wolfsburg         Union Berlin     1.890736     0.909204
#
# [166 rows x 4 columns]

# %%
# Prepara a tabela de classificação atualizada
tabela_classificacao_atualizada = tabela_classificacao[["Equipe", "Pts"]]
tabela_classificacao_atualizada["Pts"] = tabela_classificacao_atualizada["Pts"].astype(int)
display(tabela_classificacao_atualizada)
# Out:
# <ipython-input-10-ac7b0f64f543>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_classificacao_atualizada["Pts"] = tabela_classificacao_atualizada["Pts"].astype(int)
#                       Equipe  Pts
# 0           Bayer Leverkusen   42
# 1          Bayern de Munique   38
# 2                  Stuttgart   34
# 3                 RB Leipzig   33
# 4          Borussia Dortmund   27
# 5        Eintracht Frankfurt   24
# 6                 Hoffenheim   24
# 7                   Freiburg   24
# 8                 Heidenheim   20
# 9                  Wolfsburg   19
# 10                  Augsburg   18
# 11  Borussia Mönchengladbach   17
# 12             Werder Bremen   16
# 13                    Bochum   16
# 14              Union Berlin   13
# 15                  Mainz 05   10
# 16                      Köln   10
# 17              Darmstadt 98   10

# %%
# Calcula as pontuações esperadas dos jogos futuros para cada time
pontuacao_casa = tabela_jogos_faltantes.groupby("Casa").sum(numeric_only=True)[["pontos_casa"]]
pontuacao_fora = tabela_jogos_faltantes.groupby("Fora").sum(numeric_only=True)[["pontos_fora"]]
display(pontuacao_casa, pontuacao_fora)
# Out:
#                           pontos_casa
# Casa
# Augsburg                    15.718244
# Bayer Leverkusen            17.102338
# Bayern de Munique           12.732088
# Bochum                      19.167315
# Borussia Dortmund           14.200421
# Borussia Mönchengladbach    20.385942
# Darmstadt 98                 8.610617
# Eintracht Frankfurt         19.852214
# Freiburg                    18.411685
# Heidenheim                  14.187487
# Hoffenheim                  14.761085
# Köln                        13.086706
# Mainz 05                    11.443651
# RB Leipzig                  16.489984
# Stuttgart                   16.744712
# Union Berlin                13.165519
# Werder Bremen               15.906193
# Wolfsburg                   19.055054
#                           pontos_fora
# Fora
# Augsburg                     5.379479
# Bayer Leverkusen            21.834796
# Bayern de Munique           15.480912
# Bochum                       3.357531
# Borussia Dortmund           15.273531
# Borussia Mönchengladbach     5.216256
# Darmstadt 98                 4.345907
# Eintracht Frankfurt          8.377764
# Freiburg                     5.800530
# Heidenheim                   5.416571
# Hoffenheim                  11.647948
# Köln                         1.879374
# Mainz 05                     1.806988
# RB Leipzig                  11.116933
# Stuttgart                   11.018435
# Union Berlin                 3.986298
# Werder Bremen                5.602970
# Wolfsburg                    4.337313

# %%
# Atualiza a pontuação prevista na tabela de classificação
def atualizar_pontuacao_previsao(linha):
  equipe = linha["Equipe"]
  pontuacao = int(linha["Pts"]) + float(pontuacao_casa.loc[equipe, "pontos_casa"]) + float(pontuacao_fora.loc[equipe,"pontos_fora" ])
  return pontuacao

tabela_classificacao_atualizada ["Pts"] = tabela_classificacao_atualizada.apply(atualizar_pontuacao_previsao, axis=1)
tabela_classificacao_atualizada = tabela_classificacao_atualizada.sort_values(by= "Pts",ascending=False)
tabela_classificacao_atualizada = tabela_classificacao_atualizada.reset_index(drop=True)
tabela_classificacao_atualizada.index = tabela_classificacao_atualizada.index + 1

# Exibe a tabela de classificação atualizada
display(tabela_classificacao_atualizada)
# Out:
# <ipython-input-12-35e7feaf41b3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_classificacao_atualizada ["Pts"] = tabela_classificacao_atualizada.apply(atualizar_pontuacao_previsao, axis=1)
#                       Equipe        Pts
# 1           Bayer Leverkusen  80.937133
# 2          Bayern de Munique  66.213000
# 3                  Stuttgart  61.763147
# 4                 RB Leipzig  60.606917
# 5          Borussia Dortmund  56.473952
# 6        Eintracht Frankfurt  52.229978
# 7                 Hoffenheim  50.409032
# 8                   Freiburg  48.212215
# 9   Borussia Mönchengladbach  42.602197
# 10                 Wolfsburg  42.392367
# 11                Heidenheim  39.604059
# 12                  Augsburg  39.097723
# 13                    Bochum  38.524846
# 14             Werder Bremen  37.509163
# 15              Union Berlin  30.151817
# 16                      Köln  24.966080
# 17                  Mainz 05  23.250640
# 18              Darmstadt 98  22.956524

# %%
# Calcular probabilidades de vitória, derrota e empate para os jogos faltantes
def calcular_probabilidades(linha):
    pontos_casa = linha["pontos_casa"]
    pontos_fora = linha["pontos_fora"]

    total_pontos = pontos_casa + pontos_fora
    probabilidade_vitoria_casa = round(pontos_casa / total_pontos, 4)
    probabilidade_empate = round((3 - pontos_casa - pontos_fora) / total_pontos, 4)
    probabilidade_vitoria_fora = round(pontos_fora / total_pontos, 4)

    linha["prob_vitoria_casa"] = probabilidade_vitoria_casa
    linha["prob_empate"] = probabilidade_empate
    linha["prob_vitoria_fora"] = probabilidade_vitoria_fora
    linha["Time_Casa"] = linha["Casa"]
    linha["Time_Fora"] = linha["Fora"]
    return linha

# Aplicar o cálculo das probabilidades nos jogos faltantes
tabela_jogos_faltantes_com_prob = tabela_jogos_faltantes.apply(calcular_probabilidades, axis=1)

# Exibir os jogos faltantes com as probabilidades calculadas e os respectivos times
display(tabela_jogos_faltantes_com_prob[["Time_Casa", "Time_Fora", "prob_vitoria_casa", "prob_empate", "prob_vitoria_fora"]])
# Out:
#                Time_Casa  Time_Fora  prob_vitoria_casa  prob_empate  \
# 1                 Bochum   Augsburg             0.8178       0.0663
# 3           Darmstadt 98   Augsburg             0.6223       0.0731
# 4      Borussia Dortmund   Augsburg             0.8380       0.0840
# 5    Eintracht Frankfurt   Augsburg             0.9206       0.0821
# 8             Hoffenheim   Augsburg             0.7731       0.1037
# ..                   ...        ...                ...          ...
# 316           RB Leipzig  Wolfsburg             0.9872       0.4725
# 317     Bayer Leverkusen  Wolfsburg             0.9889       0.5613
# 318             Mainz 05  Wolfsburg             0.4579       0.0843
# 320    Bayern de Munique  Wolfsburg             0.9967       2.3078
# 322         Union Berlin  Wolfsburg             0.6753       0.0715
#
#      prob_vitoria_fora
# 1               0.1822
# 3               0.3777
# 4               0.1620
# 5               0.0794
# 8               0.2269
# ..                 ...
# 316             0.0128
# 317             0.0111
# 318             0.5421
# 320             0.0033
# 322             0.3247
#
# [166 rows x 5 columns]

# %%
# Selecionar apenas as colunas desejadas
colunas_selecionadas = tabela_jogos_faltantes_com_prob[["Time_Casa", "Time_Fora", "prob_vitoria_casa", "prob_empate", "prob_vitoria_fora"]]

# Salvar as colunas selecionadas em um arquivo Excel
nome_arquivo = 'tabela_jogos_faltantes_com_prob.xlsx'
colunas_selecionadas.to_excel(nome_arquivo, index=False)
